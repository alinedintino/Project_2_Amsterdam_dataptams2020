# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/rental_data_amsterdam_final.csv')
df2 = pd.read_excel('../data/Postalcodes_translation.xlsx')

# %%
#renaming column before joining
df1.rename(columns={'postcode_amsterdam': 'Postalcode'}, inplace=True)

#merging files with left join
df3 = pd.merge(df1, df2, on ='Postalcode', how ='left')

# %%
#check if duplicates
before = len(df3)
adam_postalcodes = df3.drop_duplicates(subset=None, keep='first')
after = len(df3)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
#renaming some columns
df3.rename(columns={'house_price_amsterdam': 'Rental Price','rental_agency_amsterdam': 'Rental Agency'
                    ,'bedrooms_amsterdam': 'Rooms', 'surface_amsterdam': 'Square Meter', 'Housenumber': 'House Number'
                    , 'Name_neighbourhood': 'Neighbourhood', 'Name_district': 'District', 'Name_municipality': 'Municipality'}, inplace=True)

#removing unecessary columns
df_final = df3.drop(['District2019', 'Municipality2019', 'Neighbourhood2019', 'District2019', 'Unnamed: 0'], axis = 1)

    
df_final.head()
# Out:
#    Rental Price  Rental Agency Postalcode  Rooms  Square Meter  House Number  \
# 0        2750.0  Out Amsterdam     1078JP      4           129             2
# 1        2750.0  Out Amsterdam     1078JP      4           129             4
# 2        2750.0  Out Amsterdam     1078JP      4           129             6
# 3        2750.0  Out Amsterdam     1078JP      4           129             8
# 4        2750.0  Out Amsterdam     1078JP      4           129            10
#
#        Neighbourhood      District Municipality
# 0  Scheldebuurt West  Scheldebuurt    Amsterdam
# 1  Scheldebuurt West  Scheldebuurt    Amsterdam
# 2  Scheldebuurt West  Scheldebuurt    Amsterdam
# 3  Scheldebuurt West  Scheldebuurt    Amsterdam
# 4  Scheldebuurt West  Scheldebuurt    Amsterdam

# %%
#group by district
grouped = df_final.groupby('District')['Rental Price'].agg(['mean']).sort_values('mean', ascending=False)

#styling
grouped_final = grouped.head(10).style.format('€{0:,.0f}')\
                .bar(subset=['mean'], color='indianred')

grouped_final
# Out:
# <style  type="text/css" >
#     #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 100.0%, transparent 100.0%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 62.8%, transparent 62.8%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 56.6%, transparent 56.6%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 41.1%, transparent 41.1%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 8.4%, transparent 8.4%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,indianred 5.3%, transparent 5.3%);
#         }    #T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg
#                         <td id="T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow8_col0" class="data row8 col0" >€2,326</td>
#             </tr>
#             <tr>
#                         <th id="T_75b62b8a_e317_11ea_b4b5_88e9fe556dddlevel0_row9" class="row_heading level0 row9" >De Weteringschans</th>
#                         <td id="T_75b62b8a_e317_11ea_b4b5_88e9fe556dddrow9_col0" class="data row9 col0" >€2,326</td>
#             </tr>
#     </tbody></table>

# %%
#creating a new column with buckets

df_final.loc [df_final['Square Meter'] <=20, 'm2'] = '0-20'
df_final.loc [(df_final['Square Meter'] >20) & (df_final['Square Meter'] <=40), 'm2'] = '21-40'
df_final.loc [(df_final['Square Meter'] >40) & (df_final['Square Meter'] <=60), 'm2'] = '41-60'
df_final.loc [(df_final['Square Meter'] >60) & (df_final['Square Meter'] <=80), 'm2'] = '61-80'
df_final.loc [(df_final['Square Meter'] >80) & (df_final['Square Meter'] <=100), 'm2'] = '81-100'
df_final.loc [df_final['Square Meter'] >100, 'm2'] = '+100'

df_final.head()
# Out:
#    Rental Price  Rental Agency Postalcode  Rooms  Square Meter  House Number  \
# 0        2750.0  Out Amsterdam     1078JP      4           129             2
# 1        2750.0  Out Amsterdam     1078JP      4           129             4
# 2        2750.0  Out Amsterdam     1078JP      4           129             6
# 3        2750.0  Out Amsterdam     1078JP      4           129             8
# 4        2750.0  Out Amsterdam     1078JP      4           129            10
#
#        Neighbourhood      District Municipality    m2
# 0  Scheldebuurt West  Scheldebuurt    Amsterdam  +100
# 1  Scheldebuurt West  Scheldebuurt    Amsterdam  +100
# 2  Scheldebuurt West  Scheldebuurt    Amsterdam  +100
# 3  Scheldebuurt West  Scheldebuurt    Amsterdam  +100
# 4  Scheldebuurt West  Scheldebuurt    Amsterdam  +100

# %%
#analyze data with pivot table
df_pivot = pd.pivot_table (df_final, 'Rental Price', index = ['District'],
                columns = ['m2'], aggfunc = np.mean, margins = True, margins_name = 'Grand Total', fill_value = 0)\
.sort_values(by=('Grand Total'),ascending=False)

#styling
df_style = df_pivot.head(10).style.format('{0:,.0f}')\
.background_gradient(cmap='Blues')\
                
df_style
# Out:
# <style  type="text/css" >
#     #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col4 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col5 {
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }    #T_75cf7806_e317_11ea_b4b5_88e9fe556dddrow0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T